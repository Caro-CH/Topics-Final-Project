# %% [markdown]
# exploring the GGGI raw data to generate ideas for possible project questions

# %% [markdown]
# remember to import the necessary libraries

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib as mpl

# %%
#import csv
ghostgear = pd.read_csv('https://raw.githubusercontent.com/Caro-CH/Topics-Final-Project/main/Data/gggi-export-entire-oct2018.csv')

# %%
ghostgear
# Out:
#                 Event Date  Lattitude  longitude      Gear Class  \
# 0           4/19/1981 0:00   48.47417 -122.93028             Net
# 1           4/19/1981 0:00   49.01694 -123.03889             Net
# 2            7/3/1982 0:00   48.43944 -122.82972             Net
# 3            7/3/1982 0:00   48.51417 -122.75806             Net
# 4           8/28/1983 0:00   48.46417 -122.74639             Net
# ...                    ...        ...        ...             ...
# 46312       11/4/2017 8:46   11.00478  103.05227             Net
# 46313       12/2/2017 8:46   18.34716  -65.57118            Line
# 46314        3/4/2104 0:00   48.78500 -122.84722            Line
# 46315       3/31/2106 0:00   48.47694 -122.50333  Pots and traps
# 46316  0206-06-11 08:46:02   11.34045  124.11066             Net
#
#        Count of gear at location
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# ...

# %% [markdown]
# info shows that two rows have implausible dates, probably typos. These would need to be filtered out or corrected before the data is processed. I could create a new df with dat values <=2017

# %%
ghostgear.dtypes
# Out:
# Event Date                    object
# Lattitude                    float64
# longitude                    float64
# Gear Class                    object
# Count of gear at location    float64
# dtype: object

# %%
ghostgear.describe
# Out:
# <bound method NDFrame.describe of                 Event Date  Lattitude  longitude      Gear Class  \
# 0           4/19/1981 0:00   48.47417 -122.93028             Net
# 1           4/19/1981 0:00   49.01694 -123.03889             Net
# 2            7/3/1982 0:00   48.43944 -122.82972             Net
# 3            7/3/1982 0:00   48.51417 -122.75806             Net
# 4           8/28/1983 0:00   48.46417 -122.74639             Net
# ...                    ...        ...        ...             ...
# 46312       11/4/2017 8:46   11.00478  103.05227             Net
# 46313       12/2/2017 8:46   18.34716  -65.57118            Line
# 46314        3/4/2104 0:00   48.78500 -122.84722            Line
# 46315       3/31/2106 0:00   48.47694 -122.50333  Pots and traps
# 46316  0206-06-11 08:46:02   11.34045  124.11066             Net
#
#        Count of gear at location
# 0                            NaN
# 1                            NaN
# 2                            NaN
# ...

# %%
ghostgear[['Date','Time']]=ghostgear['Event Date'].str.split(" ",expand=True)

# %%
ghostgear
# Out:
#                 Event Date  Lattitude  longitude      Gear Class  \
# 0           4/19/1981 0:00   48.47417 -122.93028             Net
# 1           4/19/1981 0:00   49.01694 -123.03889             Net
# 2            7/3/1982 0:00   48.43944 -122.82972             Net
# 3            7/3/1982 0:00   48.51417 -122.75806             Net
# 4           8/28/1983 0:00   48.46417 -122.74639             Net
# ...                    ...        ...        ...             ...
# 46312       11/4/2017 8:46   11.00478  103.05227             Net
# 46313       12/2/2017 8:46   18.34716  -65.57118            Line
# 46314        3/4/2104 0:00   48.78500 -122.84722            Line
# 46315       3/31/2106 0:00   48.47694 -122.50333  Pots and traps
# 46316  0206-06-11 08:46:02   11.34045  124.11066             Net
#
#        Count of gear at location        Date      Time
# 0                            NaN   4/19/1981      0:00
# 1                            NaN   4/19/1981      0:00
# ...

# %%
ghostgear[['Day','Month','Year']]=ghostgear['Date'].str.split("/",expand=True)

# %%
ghostgear
# Out:
#                 Event Date  Lattitude  longitude      Gear Class  \
# 0           4/19/1981 0:00   48.47417 -122.93028             Net
# 1           4/19/1981 0:00   49.01694 -123.03889             Net
# 2            7/3/1982 0:00   48.43944 -122.82972             Net
# 3            7/3/1982 0:00   48.51417 -122.75806             Net
# 4           8/28/1983 0:00   48.46417 -122.74639             Net
# ...                    ...        ...        ...             ...
# 46312       11/4/2017 8:46   11.00478  103.05227             Net
# 46313       12/2/2017 8:46   18.34716  -65.57118            Line
# 46314        3/4/2104 0:00   48.78500 -122.84722            Line
# 46315       3/31/2106 0:00   48.47694 -122.50333  Pots and traps
# 46316  0206-06-11 08:46:02   11.34045  124.11066             Net
#
#        Count of gear at location        Date      Time         Day Month  Year
# 0                            NaN   4/19/1981      0:00           4    19  1981
# ...

# %%
ghostgear.drop(labels=46316)
# Out:
#            Event Date  Lattitude  longitude      Gear Class  \
# 0      4/19/1981 0:00   48.47417 -122.93028             Net
# 1      4/19/1981 0:00   49.01694 -123.03889             Net
# 2       7/3/1982 0:00   48.43944 -122.82972             Net
# 3       7/3/1982 0:00   48.51417 -122.75806             Net
# 4      8/28/1983 0:00   48.46417 -122.74639             Net
# ...               ...        ...        ...             ...
# 46311  11/4/2017 8:46   11.00322  103.05150             Net
# 46312  11/4/2017 8:46   11.00478  103.05227             Net
# 46313  12/2/2017 8:46   18.34716  -65.57118            Line
# 46314   3/4/2104 0:00   48.78500 -122.84722            Line
# 46315  3/31/2106 0:00   48.47694 -122.50333  Pots and traps
#
#        Count of gear at location       Date  Time Day Month  Year
# 0                            NaN  4/19/1981  0:00   4    19  1981
# 1                            NaN  4/19/1981  0:00   4    19  1981
# ...

# %%
Errorfilter=(ghostgear['Year']<=2017)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-b27a2b08555e> in <module>
# ----> 1 Errorfilter=ghostgear['Year']<=2017
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     527         rvalues = extract_array(other, extract_numpy=True)
#     528
# --> 529         res_values = comparison_op(lvalues, rvalues, op)
#     530
#     531         return _construct_result(self, res_values, index=self.index, name=res_name)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     245
# ...

# %%
Errorfilter=(ghostgear['Year']<='2017')

# %%
ghostgearclean=ghostgear[Errorfilter]

# %%
ghostgearclean
# Out:
#            Event Date  Lattitude  longitude Gear Class  \
# 0      4/19/1981 0:00   48.47417 -122.93028        Net
# 1      4/19/1981 0:00   49.01694 -123.03889        Net
# 2       7/3/1982 0:00   48.43944 -122.82972        Net
# 3       7/3/1982 0:00   48.51417 -122.75806        Net
# 4      8/28/1983 0:00   48.46417 -122.74639        Net
# ...               ...        ...        ...        ...
# 46309  6/14/2017 8:46    7.88914   98.27475        Net
# 46310   7/4/2017 8:46   11.00095  103.04871        Net
# 46311  11/4/2017 8:46   11.00322  103.05150        Net
# 46312  11/4/2017 8:46   11.00478  103.05227        Net
# 46313  12/2/2017 8:46   18.34716  -65.57118       Line
#
#        Count of gear at location       Date  Time Day Month  Year
# 0                            NaN  4/19/1981  0:00   4    19  1981
# 1                            NaN  4/19/1981  0:00   4    19  1981
# 2                            NaN   7/3/1982  0:00   7     3  1982
# ...

# %%
ghostgearclean.describe
# Out:
# <bound method NDFrame.describe of            Event Date  Lattitude  longitude Gear Class  \
# 0      4/19/1981 0:00   48.47417 -122.93028        Net
# 1      4/19/1981 0:00   49.01694 -123.03889        Net
# 2       7/3/1982 0:00   48.43944 -122.82972        Net
# 3       7/3/1982 0:00   48.51417 -122.75806        Net
# 4      8/28/1983 0:00   48.46417 -122.74639        Net
# ...               ...        ...        ...        ...
# 46309  6/14/2017 8:46    7.88914   98.27475        Net
# 46310   7/4/2017 8:46   11.00095  103.04871        Net
# 46311  11/4/2017 8:46   11.00322  103.05150        Net
# 46312  11/4/2017 8:46   11.00478  103.05227        Net
# 46313  12/2/2017 8:46   18.34716  -65.57118       Line
#
#        Count of gear at location       Date  Time Day Month  Year
# 0                            NaN  4/19/1981  0:00   4    19  1981
# 1                            NaN  4/19/1981  0:00   4    19  1981
# 2                            NaN   7/3/1982  0:00   7     3  1982
# ...

# %%
ghostgearclean['Year'].max()
# Out:
# '2017'

# %%
ghostgearclean['Year'].min()
# Out:
# '1981'

# %%
sns.displot(data=ghostgearclean)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-4e13ebf1a9ef> in <module>
# ----> 1 sns.displot(data=ghostgearclean)
#
# AttributeError: module 'seaborn' has no attribute 'displot'

# %%
sns.histplot(ghostgear)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-380f4ec3e08a> in <module>
# ----> 1 sns.histplot(ghostgear)
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %% [markdown]
# why is it doing this???

# %%
penguins = sns.load_dataset("penguins")
sns.displot(penguins, x="flipper_length_mm")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-4b81e7406839> in <module>
#       1 penguins = sns.load_dataset("penguins")
# ----> 2 sns.displot(penguins, x="flipper_length_mm")
#
# AttributeError: module 'seaborn' has no attribute 'displot'

# %%
ghostgearclean.plot()

# %%
ghostgearclean.plot(x='Year',kind='hist')

# %%
ghostgearclean.groupby('Year').count()
# Out:
#       Event Date  Lattitude  longitude  Gear Class  Count of gear at location  \
# Year
# 1981           2          2          2           2                          0
# 1982           2          2          2           2                          0
# 1983           4          4          4           4                          0
# 1986           1          1          1           1                          0
# 1987           1          1          1           1                          0
# 1988           3          3          3           3                          0
# 1989           3          3          3           3                          0
# 1990          32         32         32          32                          0
# 1991          18         18         18          18                          0
# 1992          75         75         75          75                          0
# 1993          41         41         41          41                          0
# ...

# %%
ghostgearclean['Count of gear at location'] = ghostgearclean['Count of gear at location'].fillna(1)
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
